# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

data = pd.read_csv('digit-recognizer/train.csv')
data.head()
data = np.array(data)
m, n = data.shape
print(f"{n} {m}")
np.random.shuffle(data) # shuffle before splitting into dev and training sets

data_test = data[0:1000].T
Y_test = data_test[0]
X_test = data_test[1:n]
X_test = X_test / 255.


data_train = data[1000:m].T
Y_train = data_train[0]

X_train = data_train[1:n]
X_train = X_train / 255.
_,m_train = X_train.shape
n,m=X_train.shape
print(f"{n} {m}")
# Out:
# 785 42000
# 784 41000

# %%
def initParams():
    W1=np.random.rand(10,784)-0.5
    B1=np.random.rand(10,1)-0.5
    W2=np.random.rand(10,10)-0.5
    B2=np.random.rand(10,1)-0.5
    return W1,B1,W2,B2
def forwardProp(I, W1, B1, W2, B2):
   
    """  print("I shape:", I.shape)
    print("W1 shape:", W1.shape)
    print("B1 shape:", B1.shape)
    print("W2 shape:", W2.shape)
    print("B2 shape:", B2.shape)
    """

    A1 = np.matmul(W1, I) + B1
    Z1 = ReLu(A1)
    A2 = np.matmul(W2, Z1) + B2
    Z2 = softmax(A2)

 
    """print("Z1 shape:", Z1.shape)
    print("Z2 shape:", Z2.shape """

    return Z1, Z2
    
def ReLu(val):
    return np.maximum(0,val)
def softmax(A2):
    
   
    max_logits = np.max(A2, axis=0, keepdims=True)
    shifted_logits = A2 - max_logits
    exp_shifted_logits = np.exp(shifted_logits)
    
    softmax_probs = exp_shifted_logits / np.sum(exp_shifted_logits, axis=0, keepdims=True)
    
    return softmax_probs

def backProp(I, inp,Z1, Z2):
    temp = np.shape(I)[0]
    L = np.empty((10, temp))
    for i in range(temp):
        for j in range(10):
            num = I[i]
            if (num == j):
                L[j, i] = 1
            else:
                L[j, i] = 0

    ##print("Shape of L:", L.shape)

    E2 = Z2 - L
    ##print("Shape of E2:", E2.shape)

    eW2 = np.matmul(E2, (Z1.T)) / 41000
    ##print("Shape of eW2:", eW2.shape)

    eB2 =np.sum(E2,axis=1,keepdims=True)/41000
    ##print("Shape of eB2:", eB2.shape)

    E1 = np.matmul(W2.T, E2) * dxReLu(Z1)
    ##print("Shape of E1:", E1.shape)

    eW1 = np.matmul(E1,(inp.T)) / 41000
    ##print("Shape of eW1:", eW1.shape)

    eB1 = np.sum(E1,axis=1,keepdims=True)/41000
    ##eB1 = np.sum(E1, axis=1)
    ##print("Shape of eB1:", eB1.shape)

    return eW1, eB1, eW2, eB2

    
def dxReLu(Z1):
    return np.where(Z1 > 0, 1, 0)
    
def reinitParams(W1, B1, W2, B2, eW1, eB1, eW2, eB2, alpha):
    W1 = W1 - alpha * eW1
    B1 = B1 - alpha * eB1
    W2 = W2 - alpha * eW2
    B2 = B2 - alpha * eB2

  
    ##print("W1 shape:", W1.shape)
    ##print("B1 shape:", B1.shape)
    ##print("W2 shape:", W2.shape)
    ##print("B2 shape:", B2.shape)

    return W1, B1, W2, B2
def predict(L,Z2):
   
    lbl=np.argmax(Z2,0)
    


    print("lbl shape ",np.shape(lbl))
    print("label shape ",np.shape(L))
    correct_predictions = (lbl == L)
    accuracy = np.sum(lbl==L)/L.size
   
    return accuracy

# %%
W1,B1,W2,B2=initParams()
for i in range(1000):
    Z1,Z2=forwardProp(X_train,W1,B1,W2,B2)
    eW1,eB1,eW2,eB2=backProp(Y_train,X_train,Z1,Z2)
    W1,B1,W2,B2=reinitParams(W1,B1,W2,B2,eW1,eB1,eW2,eB2,0.1)
    if(i%10==0):
        accuracy=predict(Y_train,Z2)
        print(f"Accuracy at {i+1} iteration: {accuracy}")
# Out:
# lbl shape  (41000,)
# label shape  (41000,)
# Accuracy at 1 iteration: 0.0675609756097561
# lbl shape  (41000,)
# label shape  (41000,)
# Accuracy at 11 iteration: 0.12373170731707317
# lbl shape  (41000,)
# label shape  (41000,)
# Accuracy at 21 iteration: 0.21314634146341463
# lbl shape  (41000,)
# label shape  (41000,)
# Accuracy at 31 iteration: 0.28209756097560973
# lbl shape  (41000,)
# label shape  (41000,)
# Accuracy at 41 iteration: 0.3240731707317073
# lbl shape  (41000,)
# label shape  (41000,)
# Accuracy at 51 iteration: 0.36902439024390243
# lbl shape  (41000,)
# label shape  (41000,)
# Accuracy at 61 iteration: 0.4194634146341463
# lbl shape  (41000,)
# label shape  (41000,)
# Accuracy at 71 iteration: 0.4657317073170732
# lbl shape  (41000,)
# label shape  (41000,)
# Accuracy at 81 iteration: 0.5040487804878049
# lbl shape  (41000,)
# label shape  (41000,)
# Accuracy at 91 iteration: 0.5388536585365854
# lbl shape  (41000,)
# label shape  (41000,)
# Accuracy at 101 iteration: 0.5690975609756097
# lbl shape  (41000,)
# label shape  (41000,)
# Accuracy at 111 iteration: 0.5979512195121951
# lbl shape  (41000,)
# label shape  (41000,)
# Accuracy at 121 iteration: 0.6212926829268293
# lbl shape  (41000,)
# label shape  (41000,)
# Accuracy at 131 iteration: 0.643
# lbl shape  (41000,)
# label shape  (41000,)
# Accuracy at 141 iteration: 0.6610487804878049
# lbl shape  (41000,)
# label shape  (41000,)
# Accuracy at 151 iteration: 0.6785365853658537
# lbl shape  (41000,)
# label shape  (41000,)
# Accuracy at 161 iteration: 0.6933170731707317
# lbl shape  (41000,)
# label shape  (41000,)
# Accuracy at 171 iteration: 0.7051463414634146
# lbl shape  (41000,)
# label shape  (41000,)
# Accuracy at 181 iteration: 0.7173658536585366
# lbl shape  (41000,)
# label shape  (41000,)
# Accuracy at 191 iteration: 0.7279268292682927
# lbl shape  (41000,)
# label shape  (41000,)
# Accuracy at 201 iteration: 0.7368780487804878
# lbl shape  (41000,)
# label shape  (41000,)
# Accuracy at 211 iteration: 0.7455609756097561
# lbl shape  (41000,)
# label shape  (41000,)
# Accuracy at 221 iteration: 0.7525609756097561
# lbl shape  (41000,)
# label shape  (41000,)
# Accuracy at 231 iteration: 0.7595853658536585
# lbl shape  (41000,)
# label shape  (41000,)
# Accuracy at 241 iteration: 0.7659512195121951
# lbl shape  (41000,)
# label shape  (41000,)
# Accuracy at 251 iteration: 0.7722439024390244
# lbl shape  (41000,)
# label shape  (41000,)
# Accuracy at 261 iteration: 0.7781951219512195
# lbl shape  (41000,)
# label shape  (41000,)
# Accuracy at 271 iteration: 0.7836341463414634
# lbl shape  (41000,)
# label shape  (41000,)
# Accuracy at 281 iteration: 0.7891707317073171
# lbl shape  (41000,)
# label shape  (41000,)
# Accuracy at 291 iteration: 0.7937560975609756
# lbl shape  (41000,)
# label shape  (41000,)
# Accuracy at 301 iteration: 0.7987560975609757
# lbl shape  (41000,)
# label shape  (41000,)
# Accuracy at 311 iteration: 0.8022682926829269
# lbl shape  (41000,)
# label shape  (41000,)
# Accuracy at 321 iteration: 0.8065853658536586
# lbl shape  (41000,)
# label shape  (41000,)
# Accuracy at 331 iteration: 0.8102926829268293
# lbl shape  (41000,)
# label shape  (41000,)
# Accuracy at 341 iteration: 0.8138292682926829
# lbl shape  (41000,)
# label shape  (41000,)
# Accuracy at 351 iteration: 0.8167560975609756
# lbl shape  (41000,)
# label shape  (41000,)
# Accuracy at 361 iteration: 0.8192439024390243
# lbl shape  (41000,)
# label shape  (41000,)
# Accuracy at 371 iteration: 0.8225121951219512
# lbl shape  (41000,)
# label shape  (41000,)
# Accuracy at 381 iteration: 0.8248780487804878
# lbl shape  (41000,)
# label shape  (41000,)
# Accuracy at 391 iteration: 0.8274390243902439
# lbl shape  (41000,)
# label shape  (41000,)
# Accuracy at 401 iteration: 0.8298292682926829
# lbl shape  (41000,)
# label shape  (41000,)
# Accuracy at 411 iteration: 0.8318780487804878
# lbl shape  (41000,)
# label shape  (41000,)
# Accuracy at 421 iteration: 0.8337317073170731
# lbl shape  (41000,)
# label shape  (41000,)
# Accuracy at 431 iteration: 0.8352682926829268
# lbl shape  (41000,)
# label shape  (41000,)
# Accuracy at 441 iteration: 0.8365365853658536
# lbl shape  (41000,)
# label shape  (41000,)
# Accuracy at 451 iteration: 0.8385853658536585
# lbl shape  (41000,)
# label shape  (41000,)
# Accuracy at 461 iteration: 0.8409268292682927
# lbl shape  (41000,)
# label shape  (41000,)
# Accuracy at 471 iteration: 0.8424146341463414
# lbl shape  (41000,)
# label shape  (41000,)
# Accuracy at 481 iteration: 0.8435609756097561
# lbl shape  (41000,)
# label shape  (41000,)
# Accuracy at 491 iteration: 0.8449268292682927
# lbl shape  (41000,)
# label shape  (41000,)
# Accuracy at 501 iteration: 0.846170731707317
# lbl shape  (41000,)
# label shape  (41000,)
# Accuracy at 511 iteration: 0.8471951219512195
# lbl shape  (41000,)
# label shape  (41000,)
# Accuracy at 521 iteration: 0.8488536585365853
# lbl shape  (41000,)
# label shape  (41000,)
# Accuracy at 531 iteration: 0.8500487804878049
# lbl shape  (41000,)
# label shape  (41000,)
# Accuracy at 541 iteration: 0.8515853658536585
# lbl shape  (41000,)
# label shape  (41000,)
# Accuracy at 551 iteration: 0.8523658536585366
# lbl shape  (41000,)
# label shape  (41000,)
# Accuracy at 561 iteration: 0.8537073170731707
# lbl shape  (41000,)
# label shape  (41000,)
# Accuracy at 571 iteration: 0.8552195121951219
# lbl shape  (41000,)
# label shape  (41000,)
# Accuracy at 581 iteration: 0.8561707317073171
# lbl shape  (41000,)
# label shape  (41000,)
# Accuracy at 591 iteration: 0.8567073170731707
# lbl shape  (41000,)
# label shape  (41000,)
# Accuracy at 601 iteration: 0.8572926829268293
# lbl shape  (41000,)
# label shape  (41000,)
# Accuracy at 611 iteration: 0.8579268292682927
# lbl shape  (41000,)
# label shape  (41000,)
# Accuracy at 621 iteration: 0.8587073170731707
# lbl shape  (41000,)
# label shape  (41000,)
# Accuracy at 631 iteration: 0.8593414634146341
# lbl shape  (41000,)
# label shape  (41000,)
# Accuracy at 641 iteration: 0.859780487804878
# lbl shape  (41000,)
# label shape  (41000,)
# Accuracy at 651 iteration: 0.860390243902439
# lbl shape  (41000,)
# label shape  (41000,)
# Accuracy at 661 iteration: 0.8610487804878049
# lbl shape  (41000,)
# label shape  (41000,)
# Accuracy at 671 iteration: 0.861609756097561
# lbl shape  (41000,)
# label shape  (41000,)
# Accuracy at 681 iteration: 0.8624878048780488
# lbl shape  (41000,)
# label shape  (41000,)
# Accuracy at 691 iteration: 0.8628292682926829
# lbl shape  (41000,)
# label shape  (41000,)
# Accuracy at 701 iteration: 0.8631951219512195
# lbl shape  (41000,)
# label shape  (41000,)
# Accuracy at 711 iteration: 0.8635121951219512
# lbl shape  (41000,)
# label shape  (41000,)
# Accuracy at 721 iteration: 0.8641707317073171
# lbl shape  (41000,)
# label shape  (41000,)
# Accuracy at 731 iteration: 0.8648292682926829
# lbl shape  (41000,)
# label shape  (41000,)
# Accuracy at 741 iteration: 0.8652439024390244
# lbl shape  (41000,)
# label shape  (41000,)
# Accuracy at 751 iteration: 0.8658048780487805
# lbl shape  (41000,)
# label shape  (41000,)
# Accuracy at 761 iteration: 0.8661463414634146
# lbl shape  (41000,)
# label shape  (41000,)
# Accuracy at 771 iteration: 0.8669268292682927
# lbl shape  (41000,)
# label shape  (41000,)
# Accuracy at 781 iteration: 0.8675121951219512
# lbl shape  (41000,)
# label shape  (41000,)
# Accuracy at 791 iteration: 0.8682926829268293
# lbl shape  (41000,)
# label shape  (41000,)
# Accuracy at 801 iteration: 0.8687073170731707
# lbl shape  (41000,)
# label shape  (41000,)
# Accuracy at 811 iteration: 0.8692926829268293
# lbl shape  (41000,)
# label shape  (41000,)
# Accuracy at 821 iteration: 0.8698780487804878
# lbl shape  (41000,)
# label shape  (41000,)
# Accuracy at 831 iteration: 0.8702439024390244
# lbl shape  (41000,)
# label shape  (41000,)
# Accuracy at 841 iteration: 0.8707317073170732
# lbl shape  (41000,)
# label shape  (41000,)
# Accuracy at 851 iteration: 0.8711707317073171
# lbl shape  (41000,)
# label shape  (41000,)
# Accuracy at 861 iteration: 0.8714878048780488
# lbl shape  (41000,)
# label shape  (41000,)
# Accuracy at 871 iteration: 0.8719268292682927
# lbl shape  (41000,)
# label shape  (41000,)
# Accuracy at 881 iteration: 0.8721219512195122
# lbl shape  (41000,)
# label shape  (41000,)
# Accuracy at 891 iteration: 0.8724390243902439
# lbl shape  (41000,)
# label shape  (41000,)
# Accuracy at 901 iteration: 0.8730243902439024
# lbl shape  (41000,)
# label shape  (41000,)
# Accuracy at 911 iteration: 0.8736829268292683
# lbl shape  (41000,)
# label shape  (41000,)
# Accuracy at 921 iteration: 0.8742926829268293
# lbl shape  (41000,)
# label shape  (41000,)
# Accuracy at 931 iteration: 0.874609756097561
# lbl shape  (41000,)
# label shape  (41000,)
# Accuracy at 941 iteration: 0.8748048780487805
# lbl shape  (41000,)
# label shape  (41000,)
# Accuracy at 951 iteration: 0.8750243902439024
# lbl shape  (41000,)
# label shape  (41000,)
# Accuracy at 961 iteration: 0.875219512195122
# lbl shape  (41000,)
# label shape  (41000,)
# Accuracy at 971 iteration: 0.8756585365853659
# lbl shape  (41000,)
# label shape  (41000,)
# Accuracy at 981 iteration: 0.8759268292682927
# lbl shape  (41000,)
# label shape  (41000,)
# Accuracy at 991 iteration: 0.8763170731707317

# %%
def test_prediction(index, W1, B1, W2, B2):
    
    
    Z1,Z2=forwardProp(X_train[:,index,None],W1,B1,W2,B2)
    print(np.shape(X_train[:,index,None]))
    prediction =np.argmax(Z2,0)
    label = Y_train[index]
    print("Prediction: ", prediction)
    print("Label: ", label)
    img= X_train[:, index,None]
    img= img.reshape((28, 28)) * 255
    
    plt.imshow(img,interpolation='nearest')
    plt.show()

# %%
test_prediction(162, W1, B1, W2, B2)
# Out:
# (784, 1)
# Prediction:  [4]
# Label:  4

# %%
print(f"W1 {W1}")
print(f"W2 {W2}")
print(f"B1 {B1}")
print(f"B2 {B2}")

# %%
test_prediction(4, W1, B1, W2, B2)
